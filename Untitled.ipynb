# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'Performance_File.csv')

# %%
df.sort_values(by=['Avg_Fitness'], inplace=True)
df
# Out:
#      Dataset    Selector         Crossover              Mutation  \
# 19  berlin52  tournament          cycle_co    inversion_mutation
# 25  berlin52  tournament  switch_crossover    inversion_mutation
# 22  berlin52  tournament            pmx_co    inversion_mutation
# 24  berlin52  tournament  switch_crossover         swap_mutation
# 21  berlin52  tournament            pmx_co         swap_mutation
# 18  berlin52  tournament          cycle_co         swap_mutation
# 26  berlin52  tournament  switch_crossover  exponencial_mutation
# 23  berlin52  tournament            pmx_co  exponencial_mutation
# 10  berlin52         fps          cycle_co    inversion_mutation
# 20  berlin52  tournament          cycle_co  exponencial_mutation
# 9   berlin52         fps          cycle_co         swap_mutation
# 11  berlin52         fps          cycle_co  exponencial_mutation
# 0   berlin52  random_sel          cycle_co         swap_mutation
# ...
